# %% [markdown]
# **Studienummer:**

# %% [markdown]
# Dette er en colab fil, som du kan bruge til re-eksamen i anvendt statistik på HA Erhvervsøkonomi på 2. semester, 2026. Husk at gemme en lokal kopi, gem filen undervejs, og vedhæft den som bilag (.ipynb) til din besvarelse.
# HUSK: Evaluering og karaktergivning gives udelukkende på baggrund af hoved-dokument. Kopier dine visualiseringer over i hoveddokument efter behov.
#
# Held og lykke.

# %%
# Importer nødvendige pakker (gjort for jer)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Sæt Plot-stil (frivilligt, men anbefalet)

# %%
# Indlæs data
df = pd.read_excel('https://raw.githubusercontent.com/aaubs/ASE-ReExam2026-/refs/heads/main/AS_reexam26_data.xlsx')
