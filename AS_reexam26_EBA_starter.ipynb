# %% [markdown]
# **Student number:**

# %% [markdown]
# This is a Colab file for use during the Applied Business Statistics exam on EBA 2nd semester, 2026. Remember to save a local copy, save the file regularly during the exam, and attach it as an appendix (.ipynb) to your submission.
#
# REMEMBER: Grading is based exclusively on the main document. Copy your visualisations and results into the main document as needed.
#
# Good luck.

# %%
# Import required packages (done for you)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Set plot style (optional, but recommended)

# %%
# Load data
df = pd.read_csv('https://raw.githubusercontent.com/aaubs/ASE-ReExam2026-/refs/heads/main/AS_reexam26_data.csv')
